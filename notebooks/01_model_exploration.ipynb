# %%
import torch
from transformers import DistilBertTokenizer
DisitilBertForSequenceClassification
import pickle

#Load Tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('./src/models/tokenizer')

#Load model
model = DisitilBertForSequenceClassification.from_pretrained(
    './data/models/',
   num_labels=10 #Update based on your classes
)

#Load MultiLabelBinarizer
with open('./data/models/mlb_classes.pkl', 'rb') as f:
    mlb = pickle.load(f)

print(f'Number of classes: {len(mlb.classes_)}')
print(f'Classes: {mlb.classes_}')
print(f'Model parameters: {sum(p.numel() for p in model.parameters())}')
# Out:
# Running cells with 'Python 3.13.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/mtolu/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'
